# %%
import os
import glob

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

from scipy import stats
#import statannotations
from statannot import add_stat_annotation

# %%
# Open datasets

data_20 = pd.read_csv('../data/img_scout_dfs/2020/INC_coreg_skysat_scout_2020.csv')
data_21 = pd.read_csv('../data/img_scout_dfs/2021/INC_skysat_scout_2021.csv')
data_22 = pd.read_csv('../data/img_scout_dfs/2022/INC_skysat_scout_2022.csv')

dfs = [data_20, data_21, data_22]

# %%
# Dates for each year

just_scout_20 = pd.read_csv('../data/scout/scout_2020_gdf.csv')
just_scout_21 = pd.read_csv('../data/scout/scout_2021_gdf.csv')
just_scout_22 = pd.read_csv('../data/scout/scout_2022_gdf.csv')

print('2020 scout dates:\n', just_scout_20.Date.unique())
print('2021 scout dates:\n', just_scout_21.Date.unique())
print('2022 scout dates:\n', just_scout_22.Date.unique())
# Out:
# 2020 scout dates:
#  ['2020-06-18' '2020-06-25' '2020-07-01' '2020-07-09' '2020-07-15'
#  '2020-07-21' '2020-07-30' '2020-08-06' '2020-08-13' '2020-08-20'
#  '2020-09-09']
# 2021 scout dates:
#  ['2021-06-24' '2021-07-01' '2021-07-07' '2021-07-15' '2021-07-27'
#  '2021-08-03' '2021-08-10' '2021-08-17']
# 2022 scout dates:
#  ['2022-06-22' '2022-06-29' '2022-07-06' '2022-07-14' '2022-07-20'
#  '2022-07-27' '2022-08-02' '2022-08-09' '2022-08-29']

# %%
# Image dates

print('2020 img dates:\n', data_20.Date.unique())
print('2021 img dates:\n', data_21.Date.unique())
print('2022 img dates:\n', data_22.Date.unique())
# Out:
# 2020 img dates:
#  ['2020-06-18' '2020-06-25' '2020-07-09' '2020-08-06' '2020-08-13']
# 2021 img dates:
#  ['2021-07-07' '2021-07-27' '2021-08-03' '2021-08-10' '2021-08-17']
# 2022 img dates:
#  ['2022-06-22' '2022-07-06' '2022-07-20']

# %%
print("2020 mean:", just_scout_20['DM_severity'].mean())

print("2020 median:", just_scout_20['DM_severity'].median())

print("2020 max:", just_scout_20['DM_severity'].max())
# Out:
# 2020 mean: 2.254820819116041
# 2020 median: 0.2
# 2020 max: 82.0

# %%
print("2021 mean:", just_scout_21['DM_severity'].mean())

print("2021 median:", just_scout_21['DM_severity'].median())

print("2021 max:", just_scout_21['DM_severity'].max())
# Out:
# 2021 mean: 2.2983729558884156
# 2021 median: 0.05
# 2021 max: 81.125

# %%
print("2022 mean:", just_scout_22['DM_severity'].mean())

print("2022 median:", just_scout_22['DM_severity'].median())

print("2022 max:", just_scout_22['DM_severity'].max())
# Out:
# 2022 mean: 2.527338321753073
# 2022 median: 0.05
# 2022 max: 57.0

# %%
inc_20 = pd.read_csv('../data/scout/scout_incidence/scout_inc_2020.csv')
inc_21 = pd.read_csv('../data/scout/scout_incidence/scout_inc_2021.csv')
inc_22 = pd.read_csv('../data/scout/scout_incidence/scout_inc_2022.csv')

# %%
inc_20_last = inc_20[inc_20["Date"]=='2020-09-09']
inc_20_last.mean()
#inc_20_last.median()

inc_21_last = inc_21[inc_21["Date"]=='2021-08-17']
inc_21_last.mean()
inc_21_last.median()

inc_22_last = inc_22[inc_22["Date"]=='2022-08-29']
inc_22_last.mean()
#inc_22_last.median()
# Out:
# /var/folders/hg/02pmwyy14wvgdv7n1gzwlx1w0000gn/T/ipykernel_2355/1459661136.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   inc_20_last.mean()
# /var/folders/hg/02pmwyy14wvgdv7n1gzwlx1w0000gn/T/ipykernel_2355/1459661136.py:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   inc_21_last.mean()
# /var/folders/hg/02pmwyy14wvgdv7n1gzwlx1w0000gn/T/ipykernel_2355/1459661136.py:7: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   inc_21_last.median()
# /var/folders/hg/02pmwyy14wvgdv7n1gzwlx1w0000gn/T/ipykernel_2355/1459661136.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   inc_22_last.mean()
# Row             9.500000
# Panel           8.500000
# Treatment      12.500000
# PM_severity          NaN
# DM_severity    13.765625
# total_dis            NaN
# DM_inc         80.156250
# PM_inc               NaN
# dtype: float64

# %%
print("2020 mean:", inc_20['DM_inc'].mean())

print("2020 median:", inc_20['DM_inc'].median())

print("2020 max:", inc_20['DM_inc'].max())

print("2021 mean:", inc_21['DM_inc'].mean())

print("2021 median:", inc_21['DM_inc'].median())

print("2021 max:", inc_21['DM_inc'].max())

print("2022 mean:", inc_22['DM_inc'].mean())

print("2022 median:", inc_22['DM_inc'].median())

print("2022 max:", inc_22['DM_inc'].max())
# Out:
# 2020 mean: 21.628131021194605
# 2020 median: 10.0
# 2020 max: 100.0
# 2021 mean: 22.162576687116566
# 2021 median: 5.0
# 2021 max: 100.0
# 2022 mean: 13.225547835382148
# 2022 median: 0.0
# 2022 max: 100.0

# %%
# Weather station data

ws_20 = pd.read_csv('../data/weather_station/NEWA_AgritechNorth_2020.csv')
ws_21 = pd.read_csv('../data/weather_station/NEWA_crittenden_2021.csv')
ws_22 = pd.read_csv('../data/weather_station/NEWA_crittenden_2022.csv')

# %%
precip_20 = len(ws_20[ws_20['Total Precipitation']>0])/len(ws_20)
print("% days w/ precip. 2020:", precip_20)

precip_21 = len(ws_21[ws_21['Total Precipitation']>0])/len(ws_21)
print("% days w/ precip. 2021:", precip_21)

precip_22 = len(ws_22[ws_22['Total Precipitation']>0])/len(ws_22)
print("% days w/ precip. 2022:", precip_22)
# Out:
# % days w/ precip. 2020: 0.36904761904761907
# % days w/ precip. 2021: 0.4909090909090909
# % days w/ precip. 2022: 0.36231884057971014

# %%
ws_20.columns
# Out:
# Index(['date', 'Avg Air Temp (˚F)', 'Max Air Temp (˚F)', 'Min Air Temp (˚F)',
#        'Total Precipitation', 'Leaf Wethess (hrs)',
#        'Relative Humidity (hrs >= 90)', 'Solar Radiation (langleys)',
#        'Avg Wind Speed (mph)', 'Avg Soil Temp (˚F)',
#        'Avg Soil Moisture (m3/m3)'],
#       dtype='object')

# %%
air_20 = ws_20['Avg Air Temp (˚F)'].mean()
print("av. air temp. 2020:", air_20)

air_21 = ws_21['Avg Air Temp (˚F)'].mean()
print("av. air temp. 2021:", air_21)

air_22 = ws_22['Avg Air Temp (˚F)'].mean()
print("av. air temp. 2022:", air_22)
# Out:
# av. air temp. 2020: 72.94166666666666
# av. air temp. 2021: 72.15454545454546
# av. air temp. 2022: 72.3391304347826

# %%
airmin_20 = ws_20['Min Air Temp (˚F)'].mean()
print("av. min air temp. 2020:", airmin_20)

airmin_21 = ws_21['Min Air Temp (˚F)'].mean()
print("av. min air temp. 2021:", airmin_21)

airmin_22 = ws_22['Min Air Temp (˚F)'].mean()
print("av. min air temp. 2022:", airmin_22)
# Out:
# av. min air temp. 2020: 63.55119047619048
# av. min air temp. 2021: 63.18363636363635
# av. min air temp. 2022: 61.520289855072456

# %%
airmax_20 = ws_20['Max Air Temp (˚F)'].mean()
print("av. max air temp. 2020:", airmax_20)

airmax_21 = ws_21['Max Air Temp (˚F)'].mean()
print("av. max air temp. 2021:", airmax_21)

airmax_22 = ws_22['Max Air Temp (˚F)'].mean()
print("av. max air temp. 2022:", airmax_22)
# Out:
# av. max air temp. 2020: 82.32857142857142
# av. max air temp. 2021: 81.10727272727274
# av. max air temp. 2022: 83.14637681159421

# %%
lw_20 = ws_20['Leaf Wethess (hrs)'].mean()
print("av. lw 2020:", lw_20)

lw_21 = ws_21['Leaf Wethess (hrs)'].mean()
print("av. lw 2021:", lw_21)

lw_22 = ws_22['Leaf Wethess (hrs)'].mean()
print("av. lw 2022:", lw_22)
# Out:
# av. lw 2020: 7.773809523809524
# av. lw 2021: 9.672727272727272
# av. lw 2022: 12.217391304347826

# %%
rh_20 = ws_20['Relative Humidity (hrs >= 90)'].mean()
print("av. rh 2020:", rh_20)

rh_21 = ws_21['Relative Humidity (hrs >= 90)'].mean()
print("av. rh 2021:", rh_21)

rh_22 = ws_22['Relative Humidity (hrs >= 90)'].mean()
print("av. rh 2022:", rh_22)
# Out:
# av. rh 2020: 4.559523809523809
# av. rh 2021: 8.581818181818182
# av. rh 2022: 5.144927536231884

# %%
# Add VIs
def add_vis(df):
    df['ndvi']= (df['nir']-df['red'])/(df['nir']+df['red'])
    df['evi']= 2.5*(df['nir']-df['red'])/(df['nir']+6*df['red']-7.5*df['blue']+1)
    df['savi']= 1.5*(df['nir']-df['red'])/(df['nir']+df['red']+0.5)
    df['arvi']=(df['nir']-(2*df['red']-df['blue']))/(df['nir']+(2*df['red']-df['blue']))
    df['grvi']=(df['green']-df['red'])/(df['green']+df['red'])
    df['bgvi'] = df['blue']-df['green']/df['blue']+df['green']
    df['gcc']=df['green']/(df['green']+df['red']+df['blue'])
    df['gri']=df['green']/df['red']
    #df['sr']= df['nir']/df['red']
    #df['msr']= ((df['nir']/df['red'])-1)/(np.sqrt((df['nir']/df['red'])+1))
    #df['dvi']= df['nir']-df['red']
    #df['nirv']= df['ndvi']*df['nir']
    #df['tvi']=0.5*(120*(df['nir']-df['green'])-200*(df['red']-df['green']))
    return df

# %%
for df in dfs:
    add_vis(df)
    
    df['inc_class'] = 'low'
    df.loc[df['DM_inc']>25,'inc_class']= 'high'
    
    df['severity_class'] = 'low'
    df.loc[df['DM_severity']>10,'severity_class']= 'high'
    
    df.loc[df['ndvi']<=0.65,'ndvi_group']= '<0.65'
    df.loc[(df['ndvi']> 0.65)&(df['ndvi']<=0.7),'ndvi_group']='0.66-0.70'
    df.loc[(df['ndvi']> 0.7)&(df['ndvi']<=0.75),'ndvi_group']='0.71-0.75'
    df.loc[(df['ndvi']> 0.75)&(df['ndvi']<=0.8),'ndvi_group']='0.76-0.80'
    df.loc[(df['ndvi']> 0.8)&(df['ndvi']<=0.85),'ndvi_group']='0.81-0.85'
    df.loc[(df['ndvi']> 0.85),'ndvi_group']='>0.85'

# %%
# Check EVI distribution of all datasets
sns.histplot(data=data_20, x='evi')
sns.histplot(data=data_21, x='evi')
sns.histplot(data=data_22, x='evi')
# Out:
# <AxesSubplot: xlabel='evi', ylabel='Count'>

# %%
# Check NDVI distribution of all datasets
sns.histplot(data=data_20, x='ndvi')
sns.histplot(data=data_21, x='ndvi')
sns.histplot(data=data_22, x='ndvi')
# Out:
# <AxesSubplot: xlabel='ndvi', ylabel='Count'>

# %%
#Severity 2021
x = "ndvi_group"
y = "evi"
hue = "severity_class"
hue_order=['low', 'high']
order = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85']#, '>0.85']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
    ((order[2], "high"), (order[2], "low")),
    ((order[3], "high"), (order[3], "low")),
    ((order[4], "high"), (order[4], "low")),
    #((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_21, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['< 0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85'],#, '>0.85'], 
                   rotation=45)
add_stat_annotation(ax, data=data_21, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("NDVI Range", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=10%')
high_patch = mpatches.Patch(color='#FFDD33', label='>10%')

plt.legend(title='GDM Severity',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by NDVI Range 2021", fontsize=20)

plt.tight_layout()
#plt.savefig("fig3_sev_2021_fullrange.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 0.66-0.70_low v.s. 0.66-0.70_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=9.378e-01 U_stat=1.204e+03
# <0.65_low v.s. <0.65_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.746e-01 U_stat=1.300e+01
# 0.71-0.75_low v.s. 0.71-0.75_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.662e-01 U_stat=1.118e+04
# 0.76-0.80_low v.s. 0.76-0.80_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.058e-06 U_stat=1.583e+04
# 0.81-0.85_low v.s. 0.81-0.85_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.390e-01 U_stat=1.710e+02

# %%
#Incidence 2021

x = "ndvi_group"
y = "evi"
hue = "inc_class"
hue_order=['low', 'high']
order = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85']#, '>0.85']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
    ((order[2], "high"), (order[2], "low")),
    ((order[3], "high"), (order[3], "low")),
    ((order[4], "high"), (order[4], "low")),
    #((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_21, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['< 0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85'],#, '>0.85'], 
                   rotation=45)
add_stat_annotation(ax, data=data_21, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("NDVI Range", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=25%')
high_patch = mpatches.Patch(color='#FFDD33', label='>25%')

plt.legend(title='GDM Incidence',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by NDVI Range 2021", fontsize=20)

plt.tight_layout()
#plt.savefig("fig3_inc_2021_fullrange.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 0.66-0.70_low v.s. 0.66-0.70_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.020e-01 U_stat=1.892e+03
# <0.65_low v.s. <0.65_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.049e-02 U_stat=4.000e+00
# 0.71-0.75_low v.s. 0.71-0.75_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.076e-13 U_stat=2.605e+04
# 0.76-0.80_low v.s. 0.76-0.80_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.097e-56 U_stat=6.496e+04
# 0.81-0.85_low v.s. 0.81-0.85_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.362e-11 U_stat=1.299e+03

# %%
#Severity 2020

x = "ndvi_group"
y = "evi"
hue = "severity_class"
hue_order=['low', 'high']
order = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85']#, '>0.85']
pairs=[
#     ((order[0], "high"), (order[0], "low")),
#     ((order[1], "high"), (order[1], "low")),
#      ((order[2], "high"), (order[2], "low")),
     ((order[3], "high"), (order[3], "low")),
     ((order[4], "high"), (order[4], "low")),

    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_20, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85'],# '>0.85'], 
                   rotation=45)
add_stat_annotation(ax, data=data_20, x=x, y=y, order=order, hue=hue, hue_order=hue_order, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("NDVI Range", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=10%')
high_patch = mpatches.Patch(color='#FFDD33', label='>10%')

plt.legend(title='GDM Severity',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by NDVI Range 2020", fontsize=20)

plt.tight_layout()
#plt.savefig("fig3_sev_2020_fullrange.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 0.76-0.80_low v.s. 0.76-0.80_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.954e-02 U_stat=5.410e+02
# 0.81-0.85_low v.s. 0.81-0.85_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=9.913e-04 U_stat=9.760e+02

# %%
#Incidence 2020

x = "ndvi_group"
y = "evi"
hue = "inc_class"
hue_order=['low', 'high']
order = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85']#, '>0.85']
pairs=[
#     ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
     ((order[2], "high"), (order[2], "low")),
     ((order[3], "high"), (order[3], "low")),
     ((order[4], "high"), (order[4], "low")),

    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_20, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85'],# '>0.85'], 
                   rotation=45)
add_stat_annotation(ax, data=data_20, x=x, y=y, order=order, hue=hue,hue_order=hue_order, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("NDVI Range", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=25%')
high_patch = mpatches.Patch(color='#FFDD33', label='>25%')

plt.legend(title='GDM Incidence',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by NDVI Range 2020", fontsize=20)

plt.tight_layout()
#plt.savefig("fig3_inc_2020_fullrange.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 0.66-0.70_low v.s. 0.66-0.70_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.505e+02
# 0.71-0.75_low v.s. 0.71-0.75_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.027e-04 U_stat=1.300e+01
# 0.76-0.80_low v.s. 0.76-0.80_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.075e-02 U_stat=9.230e+02
# 0.81-0.85_low v.s. 0.81-0.85_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.431e-02 U_stat=1.556e+03

# %%
x = "ndvi_group"
y = "evi"
hue = "severity_class"
hue_order=['low', 'high']
order = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
     ((order[2], "high"), (order[2], "low")),
#     ((order[3], "high"), (order[3], "low")),
#     ((order[4], "high"), (order[4], "low")),
#     ((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_22, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85'], 
                   rotation=45)
add_stat_annotation(ax, data=data_22, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("NDVI Range", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=10%')
high_patch = mpatches.Patch(color='#FFDD33', label='>10%')

plt.legend(title='GDM Severity',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by NDVI Range 2022", fontsize=20)

plt.tight_layout()

#plt.savefig("fig3_sev_2022_fullrange.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 0.66-0.70_low v.s. 0.66-0.70_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.100e+01
# <0.65_low v.s. <0.65_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.646e-02 U_stat=5.740e+02
# 0.71-0.75_low v.s. 0.71-0.75_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.580e+02
# /Users/kathleenkanaley/miniconda3/envs/planetenv/lib/python3.10/site-packages/statannot/statannot.py:337: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   hue_mask = box_plotter.plot_hues[index] == hue_level

# %%
#Incidence 2022
x = "ndvi_group"
y = "evi"
hue = "inc_class"
hue_order=['low', 'high']
order = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
     ((order[2], "high"), (order[2], "low")),
     ((order[3], "high"), (order[3], "low")),
#     ((order[4], "high"), (order[4], "low")),
#     ((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_22, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['<0.65','0.66-0.70','0.71-0.75','0.76-0.80','0.81-0.85'],
                   rotation=45)
add_stat_annotation(ax, data=data_22, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("NDVI Range", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=25%')
high_patch = mpatches.Patch(color='#FFDD33', label='>25%')

plt.legend(title='GDM Incidence',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by NDVI Range 2022", fontsize=20)

plt.tight_layout()
#plt.savefig("fig3_inc_2022_fullrange.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 0.66-0.70_low v.s. 0.66-0.70_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.200e+01
# <0.65_low v.s. <0.65_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=9.460e-03 U_stat=1.552e+03
# 0.71-0.75_low v.s. 0.71-0.75_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=8.750e+02
# 0.76-0.80_low v.s. 0.76-0.80_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.000e+00
# /Users/kathleenkanaley/miniconda3/envs/planetenv/lib/python3.10/site-packages/statannot/statannot.py:337: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   hue_mask = box_plotter.plot_hues[index] == hue_level

# %% [markdown]
# ## EVI by Date

# %%
data_20.Date.unique()
# Out:
# array(['2020-06-18', '2020-06-25', '2020-07-09', '2020-08-06',
#        '2020-08-13'], dtype=object)

# %%
#Severity 2020

x = "Date"
y = "evi"
hue = "severity_class"
hue_order=['low', 'high']
order = [ '2020-08-06',
       '2020-08-13']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
    # ((order[2], "high"), (order[2], "low")),
#     ((order[3], "high"), (order[3], "low")),
#     ((order[4], "high"), (order[4], "low")),
#     ((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_20, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['2020-08-06','2020-08-13'], 
                   rotation=45)
add_stat_annotation(ax, data=data_20, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("Date", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=10%')
high_patch = mpatches.Patch(color='#FFDD33', label='>10%')

plt.legend(title='GDM Severity',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by Date 2020", fontsize=20)

plt.tight_layout()
#plt.savefig("fig4_sev_2020.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2020-08-13_low v.s. 2020-08-13_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.625e-04 U_stat=1.209e+03
# 2020-08-06_low v.s. 2020-08-06_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.208e-01 U_stat=4.650e+02

# %%
#Inc 2020

x = "Date"
y = "evi"
hue = "inc_class"
hue_order=['low', 'high']
order = ['2020-08-06',
       '2020-08-13']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
#     ((order[2], "high"), (order[2], "low")),
#     ((order[3], "high"), (order[3], "low")),
#     ((order[4], "high"), (order[4], "low")),
#     ((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_20, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['2020-08-06','2020-08-13'], 
                   rotation=45)
add_stat_annotation(ax, data=data_20, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("Date", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=25%')
high_patch = mpatches.Patch(color='#FFDD33', label='>25%')

plt.legend(title='GDM Incidence',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by Date 2020", fontsize=20)

plt.tight_layout()
plt.savefig("fig4_inc_2020.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2020-08-13_low v.s. 2020-08-13_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.256e-02 U_stat=1.618e+03
# 2020-08-06_low v.s. 2020-08-06_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.532e-04 U_stat=1.756e+03

# %%
#Severity 2021

x = "Date"
y = "evi"
hue = "severity_class"
hue_order=['low', 'high']
order = ['2021-07-27','2021-08-10',
       '2021-08-17']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
    ((order[2], "high"), (order[2], "low")),
#    ((order[3], "high"), (order[3], "low")),
 #    ((order[4], "high"), (order[4], "low")),
#     ((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_21, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['2021-07-27','2021-08-10',
       '2021-08-17'], 
                   rotation=45)
add_stat_annotation(ax, data=data_21, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("Date", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=10%')
high_patch = mpatches.Patch(color='#FFDD33', label='>10%')

plt.legend(title='GDM Severity',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by Date 2021", fontsize=20)

plt.tight_layout()
#plt.savefig("fig4_sev_2021.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2021-08-10_low v.s. 2021-08-10_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.326e-01 U_stat=4.153e+03
# 2021-07-27_low v.s. 2021-07-27_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.795e+03
# 2021-08-17_low v.s. 2021-08-17_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=4.077e+03

# %%
#Inc 2021

x = "Date"
y = "evi"
hue = "inc_class"
hue_order=['low', 'high']
order = ['2021-07-27','2021-08-10',
       '2021-08-17']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
    ((order[2], "high"), (order[2], "low")),
#    ((order[3], "high"), (order[3], "low")),
 #    ((order[4], "high"), (order[4], "low")),
#     ((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_21, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['2021-07-27','2021-08-10',
       '2021-08-17'], 
                   rotation=45)
add_stat_annotation(ax, data=data_21, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("Date", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=25%')
high_patch = mpatches.Patch(color='#FFDD33', label='>25%')

plt.legend(title='GDM Incidence',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by Date 2021", fontsize=20)

plt.tight_layout()
#plt.savefig("fig4_inc_2021.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2021-08-10_low v.s. 2021-08-10_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.040e-01 U_stat=4.523e+03
# 2021-07-27_low v.s. 2021-07-27_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.570e-01 U_stat=2.991e+03
# 2021-08-17_low v.s. 2021-08-17_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.177e-02 U_stat=4.385e+03

# %%
data_22.Date.unique()
# Out:
# array(['2022-06-22', '2022-07-06', '2022-07-20'], dtype=object)

# %%
#Severity 2022

x = "Date"
y = "evi"
hue = "severity_class"
hue_order=['low', 'high']
order = ['2022-07-06', '2022-07-20']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
#((order[2], "high"), (order[2], "low")),
#    ((order[3], "high"), (order[3], "low")),
 #    ((order[4], "high"), (order[4], "low")),
#     ((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))

ax = sns.boxplot(data=data_22, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['2022-07-06', '2022-07-20'], 
                   rotation=45)
add_stat_annotation(ax, data=data_22, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("Date", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=10%')
high_patch = mpatches.Patch(color='#FFDD33', label='>10%')

plt.legend(title='GDM Severity',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by Date 2022", fontsize=20)

plt.tight_layout()
#plt.savefig("fig4_sev_2022.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2022-07-20_low v.s. 2022-07-20_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=4.620e+02
# 2022-07-06_low v.s. 2022-07-06_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.258e-01 U_stat=4.650e+02

# %%
#Inc 2022

x = "Date"
y = "evi"
hue = "inc_class"
hue_order=['low', 'high']
order = ['2022-07-06', '2022-07-20']
pairs=[
    ((order[0], "high"), (order[0], "low")),
    ((order[1], "high"), (order[1], "low")),
#((order[2], "high"), (order[2], "low")),
#    ((order[3], "high"), (order[3], "low")),
 #    ((order[4], "high"), (order[4], "low")),
#     ((order[5], "high"), (order[5], "low"))
    ]

colors = ["#4CAF50", "#FFDD33"]
sns.set_palette(sns.color_palette(colors))
#sns.set(font="Tahoma")

ax = sns.boxplot(data=data_22, x=x, y=y, order=order, hue=hue, hue_order=hue_order, showfliers = False)
ax.set_xticklabels(labels = ['2022-07-06', '2022-07-20'], 
                   rotation=45)
add_stat_annotation(ax, data=data_22, x=x, y=y, order=order, hue=hue, box_pairs=pairs,
                    test='Mann-Whitney', loc='inside', verbose=2)


plt.xlabel("Date", fontsize=16)
plt.ylabel("EVI", fontsize= 16)

plt.ylim(0.25, 0.9)
#plt.legend(title='Disease Severity',loc='upper left', labels=['<=10%', '>10%'], bbox_to_anchor=(1.02, 1))
##
#Test creating legend artist

low_patch = mpatches.Patch(color='#4CAF50', label='<=25%')
high_patch = mpatches.Patch(color='#FFDD33', label='>25%')

plt.legend(title='GDM Incidence',
           loc='upper left',
           handles=[low_patch, high_patch],
          bbox_to_anchor=(1.02, 1))

plt.figtext(0.92, 0.5, 
            'ns : not significant\n * : p < 0.05\n ** : p < 0.01\n *** : p < 0.001\n ****: p <= 1.00e-04', 
            fontsize=12)
plt.title("EVI by Date 2022", fontsize=20)

plt.tight_layout()
#plt.savefig("fig4_inc_2022.svg")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2022-07-20_low v.s. 2022-07-20_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.828e-01 U_stat=1.117e+03
# 2022-07-06_low v.s. 2022-07-06_high: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.481e-01 U_stat=1.007e+03
