# %%
import glob 
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import statsmodels.api as sm
import pingouin as pg

# %%
pd.options.display.max_columns = None 
pd.set_option('display.expand_frame_repr', False)

# %%
data_2020 = pd.read_csv('/Users/kathleenkanaley/Desktop/grapes_from_space/data/img_scout_dfs/2020/coreg_skysat_scout_2020.csv')

# %%
data_2020.head()
# Out:
#    acquired  plot      blue     green       red       nir  row  panel        Date  Treatment Block  PM_severity  DM_severity  total_dis                                           geometry                                       centroid
# 0  20200618     1  0.040044  0.077491  0.071216  0.353575    1      1  2020-06-18        5.0    PM          0.0         0.00       0.00  POLYGON ((-77.0152645742787 42.878300949250196...     POINT (-77.0153084903025 42.8783140936145)
# 1  20200618     2  0.044693  0.081807  0.077133  0.336587    1      2  2020-06-18        9.0    PM          0.0         0.05       5.05  POLYGON ((-77.01535545427274 42.87831851925121...    POINT (-77.0153965503027 42.87833067861654)
# 2  20200618     4  0.040121  0.076396  0.070693  0.343482    1      4  2020-06-18       18.0    PM          0.0         0.00       0.50  POLYGON ((-77.01552730426143 42.87835065925314...   POINT (-77.01557007030289 42.87836309362055)
# ...

# %%
data_2020.acquired.unique()
# Out:
# array([20200618, 20200625, 20200710, 20200805, 20200812])

# %%
data_2020.describe()
# Out:
#            acquired        plot        blue       green         red         nir         row       panel   Treatment  PM_severity  DM_severity   total_dis
# count  4.990000e+02  499.000000  499.000000  499.000000  499.000000  499.000000  499.000000  499.000000  499.000000        499.0   499.000000  499.000000
# mean   2.020071e+07   85.771543    0.045098    0.068652    0.051428    0.338007    5.839679    8.336673   10.615230          0.0     1.859577    4.328214
# std    8.378428e+01   47.898444    0.010482    0.009862    0.011395    0.054498    2.976877    4.478292    6.097291          0.0     4.482729    6.307813
# min    2.020062e+07    1.000000    0.025230    0.046610    0.026124    0.243317    1.000000    1.000000    1.000000          0.0     0.000000    0.000000
# 25%    2.020062e+07   43.000000    0.036532    0.063367    0.047137    0.294178    3.000000    5.000000    5.000000          0.0     0.000000    0.350000
# ...

# %%
data_2020.iloc[3:10,3]
# Out:
# 3    0.073497
# 4    0.075070
# 5    0.075070
# 6    0.072789
# 7    0.072527
# 8    0.073935
# 9    0.073935
# Name: green, dtype: float64

# %%
data_2020[data_2020.row<7].shape
# Out:
# (249, 16)

# %%
data_2020["ndvi"] = (data_2020.nir-data_2020.red)/(data_2020.nir+data_2020.red)

# %%
data_2020
# Out:
#      acquired  plot      blue     green       red       nir  row  panel        Date  Treatment Block  PM_severity  DM_severity  total_dis                                           geometry                                       centroid      ndvi
# 0    20200618     1  0.040044  0.077491  0.071216  0.353575    1      1  2020-06-18        5.0    PM          0.0         0.00       0.00  POLYGON ((-77.0152645742787 42.878300949250196...     POINT (-77.0153084903025 42.8783140936145)  0.664702
# 1    20200618     2  0.044693  0.081807  0.077133  0.336587    1      2  2020-06-18        9.0    PM          0.0         0.05       5.05  POLYGON ((-77.01535545427274 42.87831851925121...    POINT (-77.0153965503027 42.87833067861654)  0.627123
# 2    20200618     4  0.040121  0.076396  0.070693  0.343482    1      4  2020-06-18       18.0    PM          0.0         0.00       0.50  POLYGON ((-77.01552730426143 42.87835065925314...   POINT (-77.01557007030289 42.87836309362055)  0.658633
# ...

# %%
scipy.stats.ttest_1samp(data_2020.ndvi, popmean=0.9, alternative='greater')
# Out:
# /var/folders/hg/02pmwyy14wvgdv7n1gzwlx1w0000gn/T/ipykernel_2665/2125377622.py:1: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   scipy.stats.ttest_1samp(data_2020.ndvi, popmean=0.9, alternative='greater')
# Ttest_1sampResult(statistic=inf, pvalue=0.0)

# %%
pg.ttest(data_2020.ndvi, 0.5)
# Out:
# /Users/kathleenkanaley/miniconda3/envs/planetenv/lib/python3.10/site-packages/pingouin/parametric.py:237: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   tval, pval = ttest_1samp(x, y, alternative=alternative)
# /Users/kathleenkanaley/miniconda3/envs/planetenv/lib/python3.10/site-packages/pingouin/effsize.py:788: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (x.mean() - y) / x.std(ddof=1)
# /Users/kathleenkanaley/miniconda3/envs/planetenv/lib/python3.10/site-packages/pingouin/parametric.py:280: RuntimeWarning: invalid value encountered in multiply
#   ci = np.array([tval - tcrit, tval + tcrit]) * se
#           T  dof alternative  p-val       CI95%  cohen-d BF10 power
# T-test  inf  498   two-sided    0.0  [nan, nan]      inf  nan   NaN
